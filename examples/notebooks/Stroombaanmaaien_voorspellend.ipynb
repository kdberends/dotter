# %% [markdown]
# # Voorspellend rekenen met het dottermodel
#
# In dit korte voorbeeld passen we het dottermodel toe in de context van voorspellend maaibeheer.

# %%
# %matplotlib notebook
from dotter.models import DotterModel
from dotter import tools

# %% [markdown]
# ### Laden en inspecteren van de gebiedsbeschrijving
#
# In dit voorbeeld laden we een voorbeeldmodel gebaseerd op de "Grote Beek":

# %%
deltabeek = DotterModel('../cases/grotebeek_maaibos/config.ini')
# Out:
# 2018-02-01 13:31:08 - utils.py - INFO - Start logging to ../cases/grotebeek_maaibos\output\dotter.log
# 2018-02-01 13:31:08 - models.py - INFO - Loading configuration file ../cases/grotebeek_maaibos/config.ini
# 2018-02-01 13:31:08 - models.py - INFO - Loading geometry from ../cases/grotebeek_maaibos\GroteBeek.xlsx
# 2018-02-01 13:31:08 - containers.py - DEBUG - number of timesteps: 182
# 2018-02-01 13:31:08 - containers.py - DEBUG - start time: 2016-01-01 00:00:00
# 2018-02-01 13:31:08 - containers.py - DEBUG - top time: 2016-12-30 00:00:00
# 2018-02-01 13:31:08 - containers.py - DEBUG - using spatial step of 40.0 m
# 2018-02-01 13:31:09 - models.py - INFO - Loading boundary conditions
# 2018-02-01 13:31:09 - containers.py - DEBUG - Lateral Lat_1 inserted at chainage 150
# 2018-02-01 13:31:09 - containers.py - DEBUG - Lateral Lat_2 inserted at chainage 910
# 2018-02-01 13:31:09 - containers.py - DEBUG - Lateral Lat_3 inserted at chainage 1590
# 2018-02-01 13:31:09 - models.py - DEBUG - events: []
# 2018-02-01 13:31:09 - models.py - INFO - Building friction matrix
# 2018-02-01 13:31:09 - models.py - DEBUG - Found vegetation numbers: [1]
# 2018-02-01 13:31:09 - models.py - INFO - set output path to: ../cases/grotebeek_maaibos\output
# 2018-02-01 13:31:09 - models.py - INFO - Initialised

# %% [markdown]
# Dit model bevat niet alleen gebiedsbeschrijving, maar ook metingen. Met de 'dash' functie kunnen we kijken hoe het systeem eruit ziet

# %%
deltabeek.dash()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Door het model te draaien, wordt elke tijdstap de evenwichtstoestand van het systeem berekend. Deze aanpak wordt soms 'quasi-stationair' genoemd.

# %%
deltabeek.run()
deltabeek.dash(dashtype=2)
# Out:
# 2018-02-01 13:31:16 - models.py - INFO - start model run
# 100%|████████████████████████████████████████| 183/183 [00:02<00:00, 86.04it/s]
# 2018-02-01 13:31:18 - models.py - INFO - Written waterlevel to ../cases/grotebeek_maaibos\output\waterlevel.csv
# 2018-02-01 13:31:18 - models.py - INFO - Written waterdepth to ../cases/grotebeek_maaibos\output\waterdepth.csv
# 2018-02-01 13:31:18 - models.py - INFO - Written friction to ../cases/grotebeek_maaibos\output\friction.csv
# 2018-02-01 13:31:19 - models.py - INFO - Written blockage to ../cases/grotebeek_maaibos\output\blockage.csv
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# We kunnen dit ook vergelijken met een Q(h) relatie gebaseerd op een kritieke weerstand.

# %%
tools.maaibos(model=deltabeek, 
              critical_friction=0.10, 
              show=True, 
              every=5,
              configfile=configfile)
# Out:
# 2018-02-01 13:32:13 - tools.py - INFO - Generating QH for normative friction
# 100%|██████████████████████████████████████████| 20/20 [00:03<00:00,  6.29it/s]
# 2018-02-01 13:32:16 - models.py - INFO - start model run
# 100%|████████████████████████████████████████| 183/183 [00:02<00:00, 78.02it/s]
# 2018-02-01 13:32:19 - models.py - INFO - Written waterlevel to ../cases/grotebeek_maaibos\output\waterlevel.csv
# 2018-02-01 13:32:19 - models.py - INFO - Written waterdepth to ../cases/grotebeek_maaibos\output\waterdepth.csv
# 2018-02-01 13:32:19 - models.py - INFO - Written friction to ../cases/grotebeek_maaibos\output\friction.csv
# 2018-02-01 13:32:19 - models.py - INFO - Written blockage to ../cases/grotebeek_maaibos\output\blockage.csv
# <img src="data:image/png;base64,..." width="1000">
# True
