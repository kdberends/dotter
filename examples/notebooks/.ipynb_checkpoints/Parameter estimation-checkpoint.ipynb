# %% [markdown]
# # Parameter estimation
#
# This notebook shows how to use the Dottermodel to estimate the friction parameter in a stream.
#
# First, we import the dotter model

# %%
# %matplotlib inline
from dotter import dotter
from dotter import notebook
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %%
stream = dotter.build_model_from_config('../cases/example_03/config.ini')
measurements = np.loadtxt('../cases/example_03/measurements.csv', skiprows=1, delimiter=',')
# Out:
# Initialising geometry...
# Loading lateral sources...
# Generating computational grid...
# Planting vegetation...
# Loading events...
# Model loaded

# %%
Q = measurements.T[0]
h_up = measurements.T[1]
h_down = measurements.T[2]
t = list(range(len(Q)))

fig = plt.figure()
axes = fig.subplots(2)
axes[0].set_ylabel('Manning coefficient')
axes[0].set_xlabel('Days')
axes[1].set_xlabel('Upstream waterlevel')
axes[1].set_ylabel('Manning coefficient')
frictionvalues = []

for q, hup, hdown, it in zip(Q, h_down, h_up, t):
    stream.parameters['h'] = hdown - 5.13
    stream.parameters['Q'] = q
    stream.generate_grid()
    friction, res = dotter.estimate_roughness(stream, hup, 'waterlevel')
    frictionvalues.append(friction[0])
    axes[0].plot(it, friction, '.k')
    axes[1].plot(hup, friction, '.k')
    display.clear_output(wait=True)
    display.display(fig)

np.savetxt('frictionvalues.csv', frictionvalues, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1b5d751459e3> in <module>()
#      13     stream.parameters['Q'] = q
#      14     stream.generate_grid()
# ---> 15     friction, res = dotter.estimate_roughness(stream, hup, 'waterlevel')
#      16     frictionvalues.append(friction[0])
#      17     ax.plot(it, friction, '.')
#
# e:\work\dotter\dotter\dotter\dotter.py in estimate_roughness(stream, measurement, variable)
#      83                                               tol=0.001,
#      84                                               method="Nelder-Mead",
# ---> 85                                               options=dict(maxiter=50))
#      86
#      87     return res.x, res
#
# C:\Program Files\Anaconda3\envs\python36\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     436                       callback=callback, **options)
#     437     elif meth == 'nelder-mead':
# --> 438         return _minimize_neldermead(fun, x0, args, callback, **options)
#     439     elif meth == 'powell':
#     440         return _minimize_powell(fun, x0, args, callback, **options)
#
# C:\Program Files\Anaconda3\envs\python36\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, **unknown_options)
#     531         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     532         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 533         fxr = func(xr)
#     534         doshrink = 0
#     535
#
# C:\Program Files\Anaconda3\envs\python36\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# e:\work\dotter\dotter\dotter\dotter.py in _gof(n, *args)
#     100     stream.parameters['constant_friction'] = n
#     101
# --> 102     results, stream = run_model(stream, stoptime=1, verbose=False)
#     103
#     104     #sys.stdout.write("n: {}\n measurement: {}\n model: {}\n".format(n, measurement, results[variable].values[0][0]))
#
# e:\work\dotter\dotter\dotter\dotter.py in run_model(stream, restart, starttime, stoptime, write_output, verbose)
#      60                                   stoptime=stoptime,
#      61                                   write_to_file=write_output,
# ---> 62                                   verbose=verbose)
#      63     return results, stream
#      64
#
# e:\work\dotter\dotter\dotter\Functions.py in qs_solver(geometry, restart, verbose, write_to_file, starttime, stoptime)
#     292         results = {'x': pd.DataFrame(index=time, columns=geometry.grid_x),
#     293                    'n': pd.DataFrame(index=time, columns=geometry.grid_x),
# --> 294                    'fa': pd.DataFrame(index=time, columns=geometry.grid_x),
#     295                    'waterdepth': pd.DataFrame(index=time, columns=geometry.grid_x),
#     296                    'waterlevel': pd.DataFrame(index=time, columns=geometry.grid_x),
#
# C:\Program Files\Anaconda3\envs\python36\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# C:\Program Files\Anaconda3\envs\python36\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     446                         v = np.empty(len(index), dtype=dtype)
#     447
# --> 448                     v.fill(np.nan)
#     449                 else:
#     450                     v = data[k]
#
# KeyboardInterrupt:

# %%
pl.plot(pl.randn(100))
    display.clear_output(wait=True)
    display.display(pl.gcf())
    time.sleep(1.0)

# %%
ax = fig.add_subplot(111)
ax.plot(list(range(len(frictionvalues))), frictionvalues, '.')

plt.show()
